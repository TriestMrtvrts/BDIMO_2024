# %%
# import pandas as pd
# train_data = pd.read_csv('train.csv')
# user_data = pd.read_csv('user.csv')
# video_data = pd.read_csv('video.csv')
# owner_data = pd.read_csv('owner.csv')

# %%
from pprint import pprint

import numpy as np
import pandas as pd


from tqdm.auto import tqdm

from implicit.nearest_neighbours import TFIDFRecommender, BM25Recommender
from implicit.als import AlternatingLeastSquares

from rectools import Columns
from rectools.dataset import Dataset
from rectools.metrics import Precision, Recall, MeanInvUserFreq, Serendipity, calc_metrics
from rectools.models import ImplicitItemKNNWrapperModel, RandomModel, PopularModel
from rectools.model_selection import TimeRangeSplitter, cross_validate

# %%
ratings = pd.read_csv(
    "train2.csv",
    low_memory=False,
    names=[Columns.Weight, Columns.Datetime, Columns.User, Columns.Item]
)

users = pd.read_csv("user_cleaned.csv", low_memory=False,
                    names=[Columns.User, "gender", "age", "language", "city", "time"]
                    )
movies = pd.read_csv(
    "vid_n_own.csv",
    low_memory=False,
    names=[Columns.Item, "owner_id", "dur", "st", "subs", "ls_date", "city", "create_date"],
    encoding_errors="ignore",
)
ratings = ratings.drop(ratings.index[0])

# %%
ratings = ratings.astype(int)
movies = movies.astype(int)
users = users.astype(int)

# %%
ratings['datetime'] = pd.to_datetime(ratings['datetime'], unit='ms')
users['time'] = users['time']
movies['create_date'] = movies['create_date'] // 1000
movies['ls_date'] = movies['ls_date'] // 1000
movies['st'] = movies["st"] // 1000

# %%
users = users.loc[users["user_id"].isin(ratings["user_id"])].copy()
movies = movies.loc[movies["item_id"].isin(ratings["item_id"])].copy()

# %%
user_features_frames = []
for feature in ["gender", "age", "language", "city", "time"]:
    feature_frame = users.reindex(columns=["user_id", feature])
    feature_frame.columns = ["id", "value"]
    feature_frame["feature"] = feature
    user_features_frames.append(feature_frame)
user_features = pd.concat(user_features_frames)

# %%
movies_features_frames = []
for feature in ["owner_id", "dur", "st", "subs", "ls_date", "city"]:
    feature_frame = movies.reindex(columns=["item_id", feature])
    feature_frame.columns = ["id", "value"]
    feature_frame["feature"] = feature
    movies_features_frames.append(feature_frame)
movies_features = pd.concat(movies_features_frames)

# %%
dataset = Dataset.construct(
    ratings,
    user_features_df=user_features,
    item_features_df=movies_features,
    cat_user_features=["gender"],
    cat_item_features=["city", "owner_id"],
    make_dense_user_features=False,
    make_dense_item_features=False
    # for `sparse` format
)

# %%
dataset
# Out:
# Dataset(user_id_map=IdMap(external_ids=array([126492, 117764,  11347, ...,  37071,   3642, 146066])), item_id_map=IdMap(external_ids=array([228525, 204343, 201337, ...,  17872,  53341, 135163])), interactions=Interactions(df=         user_id  item_id  weight                datetime
# 1              0        0     1.0 2023-10-02 18:24:39.748
# 2              1        1     1.0 2023-10-02 18:24:39.760
# 3              2        2     1.0 2023-10-02 18:24:39.988
# 4              3        3     1.0 2023-10-02 18:24:40.451
# 5              3        3     1.0 2023-10-02 18:24:40.451
# ...          ...      ...     ...                     ...
# 5657320    45079    41511     1.0 2023-10-10 14:00:05.821
# 5657321    87648    52566     1.0 2023-10-10 14:00:06.884
# 5657322    12957    11657     1.0 2023-10-10 14:00:07.292
# 5657323    12646      524     1.0 2023-10-10 14:00:07.461
# 5657324    88477    14776    10.0 2023-10-10 14:00:07.541
#
# [5657324 rows x 4 columns]), user_features=SparseFeatures(values=<152911x6 sparse matrix of type '<class 'numpy.float32'>'
# 	with 764555 stored elements in Compressed Sparse Row format>, names=(('age', '__is_direct_feature'), ('language', '__is_direct_feature'), ('city', '__is_direct_feature'), ('time', '__is_direct_feature'), ('gender', 0), ('gender', 1))), item_features=SparseFeatures(values=<228506x8253 sparse matrix of type '<class 'numpy.float32'>'
('city', 254), ('city', 428), ('city', 472), ('city', 365), ('city', 128), ('city', 454), ('city', 421), ('city', 207), ('city', 250), ('city', 545), ('city', 317), ('city', 300), ('city', 274), ('city', 247), ('city', 387), ('city', 518), ('city', 208), ('city', 366), ('city', 550), ('city', 284), ('city', 559), ('city', 344), ('city', 74), ('city', 0), ('city', 376), ('city', 415), ('city', 401), ('city', 39), ('city', 227), ('city', 71), ('city', 160), ('city', 34), ('city', 566), ('city', 145), ('city', 259), ('city', 461), ('city', 255), ('city', 333), ('city', 484), ('city', 315), ('city', 527), ('city', 60), ('city', 170), ('city', 210), ('city', 400), ('city', 452), ('city', 162), ('city', 57), ('city', 151), ('city', 289), ...

# %%
from rectools.models import ImplicitALSWrapperModel

# %%
from implicit.als import AlternatingLeastSquares
from implicit.nearest_neighbours import TFIDFRecommender, BM25Recommender
from rectools.models import ImplicitItemKNNWrapperModel, RandomModel, PopularModel

# %%
import rectools

# %%
# n_splits = 2
# 
# splitter = TimeRangeSplitter(
#     test_size="15D",
#     n_splits=n_splits,
#     filter_already_seen=True,
#     filter_cold_items=True,
#     filter_cold_users=True,
# )

# %%
# splitter.get_test_fold_borders(dataset.interactions)
# Out:
# [(Timestamp('2023-10-02 00:00:00', freq='15D'),
#   Timestamp('2023-10-17 00:00:00', freq='15D')),
#  (Timestamp('2023-10-17 00:00:00', freq='15D'),
#   Timestamp('2023-11-01 00:00:00', freq='15D'))]

# %%
# Take few simple models to compare
# models = {
#     "random": RandomModel(random_state=42),
#     "popular": PopularModel(),
#     "most_raited": PopularModel(popularity="sum_weight"),
#     "tfidf_k=5": ImplicitItemKNNWrapperModel(model=TFIDFRecommender(K=5)),
#     "tfidf_k=10": ImplicitItemKNNWrapperModel(model=TFIDFRecommender(K=10)),
#     "bm25_k=10_k1=0.05_b=0.1": ImplicitItemKNNWrapperModel(model=BM25Recommender(K=10, K1=0.05, B=0.1)),
#     }

# models = {
#     "bm25_k=25_k1=0.05_b=0.2": ImplicitItemKNNWrapperModel(model=BM25Recommender(K=25, K1=0.05, B=0.2))
# }
# # We will calculate several classic (precision@k and recall@k) and "beyond accuracy" metrics
# metrics = {
#     "prec@1": Precision(k=1),
#     "prec@10": Precision(k=10),
#     "recall": Recall(k=10),
#     "novelty": MeanInvUserFreq(k=10),
#     "serendipity": Serendipity(k=10),
# }
# 
# K_RECS = 10
# "bm25_k=50_k1=0.5_b=0.01": ImplicitItemKNNWrapperModel(model=BM25Recommender(K=50, K1=0.5, B=0.01)) 0.049

# %%
# cv_results = cross_validate(
#     dataset=dataset,
#     splitter=splitter,
#     models=models,
#     metrics=metrics,
#     k=K_RECS,
#     filter_viewed=True,
# )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[343], line 1
# ----> 1 cv_results = cross_validate(
#       2     dataset=dataset,
#       3     splitter=splitter,
#       4     models=models,
#       5     metrics=metrics,
#       6     k=K_RECS,
#       7     filter_viewed=True,
#       8 )
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/rectools/model_selection/cross_validate.py:130, in cross_validate(dataset, splitter, metrics, models, k, filter_viewed, items_to_recommend)
#     128 for model_name, model in models.items():
#     129     model.fit(fold_dataset)
# --> 130     reco = model.recommend(  # 1x internal
#     131         users=test_users,
#     132         dataset=fold_dataset,
#     133         k=k,
#     134         filter_viewed=filter_viewed,
#     135         items_to_recommend=item_ids_to_recommend,
#     136     )
#     137     metric_values = calc_metrics(
#     138         metrics,
#     139         reco=reco,
#    (...)
#     142         catalog=catalog,
#     143     )
#     144     res = {"model": model_name, "i_split": split_info["i_split"]}
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/rectools/models/base.py:147, in ModelBase.recommend(self, users, dataset, k, filter_viewed, items_to_recommend, add_rank_col, assume_external_ids, return_external_ids)
#     141         raise TypeError("Internal user ids are always integer")
#     143 sorted_item_ids_to_recommend = self._get_sorted_item_ids_to_recommend(
#     144     items_to_recommend, dataset, assume_external_ids
#     145 )
# --> 147 reco_user_ids, reco_item_ids, reco_scores = self._recommend_u2i(
#     148     user_ids,
#     149     dataset,
#     150     k,
#     151     filter_viewed,
#     152     sorted_item_ids_to_recommend,
#     153 )
#     155 if return_external_ids:
#     156     reco_user_ids = dataset.user_id_map.convert_to_external(reco_user_ids)
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/rectools/models/implicit_knn.py:74, in ImplicitItemKNNWrapperModel._recommend_u2i(self, user_ids, dataset, k, filter_viewed, sorted_item_ids_to_recommend)
#      72 all_scores: tp.List[float] = []
#      73 for user_id in tqdm(user_ids, disable=self.verbose == 0):
# ---> 74     reco_ids, reco_scores = self._recommend_for_user(
#      75         user_id,
#      76         user_items,
#      77         k,
#      78         filter_viewed,
#      79         sorted_item_ids_to_recommend,
#      80     )
#      81     all_user_ids.extend([user_id] * len(reco_ids))
#      82     all_reco_ids.extend(reco_ids)
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/rectools/models/implicit_knn.py:115, in ImplicitItemKNNWrapperModel._recommend_for_user(self, user_id, user_items, k, filter_viewed, sorted_item_ids)
#     111     n_items = k + viewed_ids.size
#     112     reco, scores = self.model.recommend(
#     113         user_id, user_items[user_id], N=n_items, filter_already_liked_items=False
#     114     )
# --> 115     valid_items_mask = fast_isin_for_sorted_test_elements(reco, viewed_ids, invert=True)
#     117 reco = reco[valid_items_mask][:k]
#     118 scores = scores[valid_items_mask][:k]
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/rectools/utils/array_set_ops.py:195, in fast_isin_for_sorted_test_elements(elements, sorted_test_elements, invert)
#     192         return np.ones(elements.size, dtype=bool)
#     193     return np.zeros(elements.size, dtype=bool)
# --> 195 searched_indices = np.searchsorted(sorted_test_elements, elements, side="left")
#     197 # If there are some values in `elements` bigger than the max value in `sorted_test_elements`,
#     198 # they will get index equal to `sorted_test_elements.size`
#     199 searched_indices = np.minimum(searched_indices, sorted_test_elements.size - 1)
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1400, in searchsorted(a, v, side, sorter)
#    1332 @array_function_dispatch(_searchsorted_dispatcher)
#    1333 def searchsorted(a, v, side='left', sorter=None):
#    1334     """
#    1335     Find indices where elements should be inserted to maintain order.
#    1336
#    (...)
#    1398
#    1399     """
# -> 1400     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File ~/programming/BDIMO 2024/.venv2/lib/python3.9/site-packages/numpy/core/fromnumeric.py:58, in _wrapfunc(obj, method, *args, **kwds)
#      55 if bound is None:
#      56     return _wrapit(obj, method, *args, **kwds)
# ---> 58 try:
#      59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#
# KeyboardInterrupt:

# %%
# pd.DataFrame(cv_results["splits"])

# %%
# pd.DataFrame(cv_results["metrics"]).head(100)

# %%
# pivot_results = (
#     pd.DataFrame(cv_results["metrics"])
#     .drop(columns="i_split")
#     .groupby(["model"], sort=False)
#     .agg(["mean", "std"])
# )
# mean_metric_subset = [(metric, "mean") for metric in pivot_results.columns.levels[0]]
# (
#     pivot_results.style
#     .highlight_min(subset=mean_metric_subset, color='lightcoral', axis=0)
#     .highlight_max(subset=mean_metric_subset, color='lightgreen', axis=0)
# )
# "bm25_k=20_k1=0.5_b=0.01" : 0.048, 0.032, 0.036
# "bm25_k=10_k1=0.5_b=0.03": ImplicitItemKNNWrapperModel(model=BM25Recommender(K=10, K1=0.5, B=0.03))
# "bm25_k=10_k1=0.5_b=0.05": ImplicitItemKNNWrapperModel(model=BM25Recommender(K=10, K1=0.5, B=0.05))
# Out:
# <style type="text/css">
# #T_bfc3c_row1_col0, #T_bfc3c_row5_col2, #T_bfc3c_row7_col4, #T_bfc3c_row8_col6, #T_bfc3c_row8_col8 {
#   background-color: lightcoral;
# }
# #T_bfc3c_row7_col6, #T_bfc3c_row7_col8, #T_bfc3c_row8_col4, #T_bfc3c_row10_col2, #T_bfc3c_row11_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bfc3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfc3c_level0_col0" class="col_heading level0 col0" colspan="2">prec@1</th>
#       <th id="T_bfc3c_level0_col2" class="col_heading level0 col2" colspan="2">prec@10</th>
#       <th id="T_bfc3c_level0_col4" class="col_heading level0 col4" colspan="2">recall</th>
#       <th id="T_bfc3c_level0_col6" class="col_heading level0 col6" colspan="2">novelty</th>
#       <th id="T_bfc3c_level0_col8" class="col_heading level0 col8" colspan="2">serendipity</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_bfc3c_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_bfc3c_level1_col1" class="col_heading level1 col1" >std</th>
#       <th id="T_bfc3c_level1_col2" class="col_heading level1 col2" >mean</th>
#       <th id="T_bfc3c_level1_col3" class="col_heading level1 col3" >std</th>
#       <th id="T_bfc3c_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_bfc3c_level1_col5" class="col_heading level1 col5" >std</th>
#       <th id="T_bfc3c_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_bfc3c_level1_col7" class="col_heading level1 col7" >std</th>
#       <th id="T_bfc3c_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_bfc3c_level1_col9" class="col_heading level1 col9" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfc3c_level0_row0" class="row_heading level0 row0" >bm25_k=25_k1=0.05_b=0.2</th>
#       <td id="T_bfc3c_row0_col0" class="data row0 col0" >0.044940</td>
#       <td id="T_bfc3c_row0_col1" class="data row0 col1" >0.002075</td>
#       <td id="T_bfc3c_row0_col2" class="data row0 col2" >0.030753</td>
#       <td id="T_bfc3c_row0_col3" class="data row0 col3" >0.006240</td>
#       <td id="T_bfc3c_row0_col4" class="data row0 col4" >0.034236</td>
#       <td id="T_bfc3c_row0_col5" class="data row0 col5" >0.007830</td>
#       <td id="T_bfc3c_row0_col6" class="data row0 col6" >8.065087</td>
#       <td id="T_bfc3c_row0_col7" class="data row0 col7" >3.441802</td>
#       <td id="T_bfc3c_row0_col8" class="data row0 col8" >0.000064</td>
#       <td id="T_bfc3c_row0_col9" class="data row0 col9" >0.000045</td>
#     </tr>
#     <tr>
#       <th id="T_bfc3c_level0_row1" class="row_heading level0 row1" >bm25_k=25_k1=0.05_b=0.23</th>
#       <td id="T_bfc3c_row1_col0" class="data row1 col0" >0.044572</td>
#       <td id="T_bfc3c_row1_col1" class="data row1 col1" >0.003226</td>
#       <td id="T_bfc3c_row1_col2" class="data row1 col2" >0.030677</td>
#       <td id="T_bfc3c_row1_col3" class="data row1 col3" >0.006559</td>
#       <td id="T_bfc3c_row1_col4" class="data row1 col4" >0.034105</td>
#       <td id="T_bfc3c_row1_col5" class="data row1 col5" >0.008091</td>
#       <td id="T_bfc3c_row1_col6" class="data row1 col6" >8.147286</td>
#       <td id="T_bfc3c_row1_col7" class="data row1 col7" >3.392254</td>
#       <td id="T_bfc3c_row1_col8" class="data row1 col8" >0.000065</td>
#       <td id="T_bfc3c_row1_col9" class="data row1 col9" >0.000044</td>
#     </tr>
#     <tr>
#       <th id="T_bfc3c_level0_
#       <td id="T_bfc3c_row5_col8" class="data row5 col8" >0.000066</td>
#       <td id="T_bfc3c_row5_col9" class="data row5 col9" >0.000043</td>
#     </tr>
#     <tr>
#       <th id="T_bfc3c_level0_row6" class="row_heading level0 row6" >bm25_k=22_k1=0.052_b=0.2</th>
#       <td id="T_bfc3c_row6_col0" class="data row6 col0" >0.044814</td>
#       <td id="T_bfc3c_row6_col1" class="data row6 col1" >0.002077</td>
#       <td id="T_bfc3c_row6_col2" class="data row6 col2" >0.030728</td>
#       <td id="T_bfc3c_row6_col3" class="data row6 col3" >0.006338</td>
#       <td id="T_bfc3c_row6_col4" class="data row6 col4" >0.034174</td>
#       <td id="T_bfc3c_row6_col5" class="data row6 col5" >0.007887</td>
#       <td id="T_bfc3c_row6_col6" class="data row6 col6" >8.109740</td>
#       <td id="T_bfc3c_row6_col7" class="data row6 col7" >3.396973</td>
#       <td id="T_bfc3c_row6_col8" class="data row6 col8" >0.000065</td>
#       <td id="T_bfc3c_row6_col9" class="data row6 col9" >0.000044</td>
#     </tr>
#     <

# %%
# recos = model.recommend(
#     users=ratings[Columns.User].unique(),
#     dataset=dataset,
#     k=10,
#     filter_viewed=True,
# )

# %%
# user_id = 126492

# %%
# recos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 recos
#
# NameError: name 'recos' is not defined

# %%
# recos.to_csv('ffffflllsst.csv', index=False)

# %%
# from tqdm import tqdm
# import numpy as np
# 
# us = pd.read_csv('user_cleaned_copy.csv').iterrows()
# dt = []
# for idx, row in tqdm(recos):
#     f = [row[1], []]
#     user_id = row[1]
#     user_recos = recos.query(f"user_id == @user_id").merge(movies, on="item_id")
#     for idx2, row2 in user_recos.iterrows():
#         f[1].append(row2[1])
#     dt.append(f)
# usr = []
# vi = []

# %%
model = rectools.models.ImplicitItemKNNWrapperModel(model=BM25Recommender(K=5, K1=0.5, B=0.03))
model.fit(dataset)
recos = model.recommend(
    users=ratings[Columns.User].unique(),
    dataset=dataset,
    k=10,
    filter_viewed=True,
)

# %%
g = list(recos.iterrows())
ans = {}
for idx, row in g:
    us_id = int(row['user_id'])
    item_id = int(row['item_id'])
    if us_id in ans:
        ans[us_id].append(item_id)
    else:
        ans[us_id] = [item_id]

# %%
dt = []
us = pd.read_csv('user_cleaned_copy.csv')
g = [188589, 131005, 51799, 166282, 34204, 217384, 169519, 132648, 45311, 24671]
us = list(us.iterrows())
for idx, rw in us:
    i = int(rw['a'])
    if i in ans:
        t = [i, []]
        f =[]
        k = list(set(ans[i]))
        if len(k)>=10:
            f = k[:10]
        else:
            f = k
            q = 0
            while len(f)<10:
                if g[q] not in f:
                    f.append(g[q])
                q+=1
        t[1] = f
        dt.append(t)
    else:
        dt.append([i, g])

# %%
usr = []
vi = []
for i in dt:
    usr.append(int(i[0]))
    vi.append(' '.join(map(lambda x: str(int(x)), i[1])))
np.array(usr).astype('int')
recommendation = pd.DataFrame()
recommendation["user_id"] = np.array(usr).astype('int')
recommendation["recommendation"] = np.array(vi)
recommendation.to_csv("sol_K=25_K1=0-05_B=0-2.csv", index=False)

# %%
recommendation.to_csv("123123123123sol_K=26_K1=0-05_B=0-2.csv", index=False)
